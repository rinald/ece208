# %%
from numan.methods import gauss_seidel

# %%
gauss_seidel([[16, 3], [7, -11]], [11, 13])
# Out:
# [0.687500000000000, -1.18181818181818]
# [0.909090909090909, -0.744318181818182]
# [0.827059659090909, -0.603305785123967]
# [0.800619834710744, -0.655507489669422]
# [0.810407654313017, -0.672332832456799]
# [0.813562406085650, -0.666104219982626]
# [0.812394541246742, -0.664096650672768]
# [0.812018122001144, -0.664839837388437]
# [0.812157469510332, -0.665079376908363]
# [0.812202383170318, -0.664990701220698]

# %%
gauss_seidel([[4, 2, 1], [1, -3, 1], [3, 2, -6]], [4, 6, -11])
# Out:
# [1.00000000000000, -2.00000000000000, 1.83333333333333]
# [1.54166666666667, -1.05555555555556, 1.66666666666667]
# [1.11111111111111, -0.930555555555555, 2.25231481481481]
# [0.902199074074074, -0.878858024691358, 2.07870370370370]
# [0.919753086419753, -1.00636574074074, 1.99148019547325]
# [1.00531282150206, -1.02958890603567, 1.95775462962963]
# [1.02535579561043, -1.01231084962277, 1.99279344207247]
# [1.00795706429327, -0.993950254105700, 2.00857428126429]
# [0.994831556736778, -0.994489551480815, 2.00599511411140]
# [0.995745997212557, -0.999724443050607, 1.99925259454145]
