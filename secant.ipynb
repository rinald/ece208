# %%
from util import *

# %%
secant(x**2-6, 2, 3, exact=True)
# Out:
# p1 = 12/5 ~= 2.40000000000000
# p2 = 22/9 ~= 2.44444444444444
# p3 = 267/109 ~= 2.44954128440367
# p4 = 11760/4801 ~= 2.44948968964799
# p5 = 2093258/854569 ~= 2.44948974278262
# p6 = 24616714347/10049731549 ~= 2.44948974278318
#
# Root of x**2 - 6 within range:
# 2.44948974278318

# %%
secant(x**3-20, 4, 5.5)
# Out:
# p1 ~= 3.35531135531136
# p2 ~= 3.05888392020264
# p3 ~= 2.77968299686722
# p4 ~= 2.72193285219057
# p5 ~= 2.71459512950069
# p6 ~= 2.71441810713640
# p7 ~= 2.71441761662698
# p8 ~= 2.71441761659491
#
# Root of x**3 - 20 within range:
# 2.71441761659491

# %%
secant(exp(-x)-x, 0, 1, t=10**-4)
# Out:
# p1 ~= 0.612699836780282
# p2 ~= 0.563838389161074
# p3 ~= 0.567170358419745
# p4 ~= 0.567143306604963
#
# Root of -x + exp(-x) within range:
# 0.567143290409784

# %%
secant(x*exp(x)-cos(x), 0, 1, t=10**-4)
# Out:
# p1 ~= 0.314665337800771
# p2 ~= 0.446728144591334
# p3 ~= 0.531705860644546
# p4 ~= 0.516904467567368
# p5 ~= 0.517747465271495
# p6 ~= 0.517757370754217
#
# Root of x*exp(x) - cos(x) within range:
# 0.517757363682458

# %%
plot_function(lambda x: x**2-4, (-1, 1))
plot_function(lambda x: 2*x-3, (-1, 1))
